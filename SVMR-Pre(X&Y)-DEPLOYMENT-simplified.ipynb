# %%
import pickle
loaded_model=pickle.load(open('finalized_model_SVMR-X&Y.sav','rb'))
scx=pickle.load(open('scx.pkl','rb'))
scy=pickle.load(open('scy.pkl','rb'))

# %%
preinput=scx.transform([[23,33,3,1,0]])
preinput
# Out:
# C:\Users\deepa\ANACONDA3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.17608405,  0.36064528,  1.59428492,  1.02378711, -0.50466988]])

# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_SVMR-X&Y.sav",'rb'))
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([-0.79025561])

# %%
preoutput=scy.inverse_transform([result])
preoutput
# Out:
# array([[3849.60912671]])
