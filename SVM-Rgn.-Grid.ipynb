# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')
dataset=pd.get_dummies(dataset,drop_first=True)
independent=dataset[['age', 'bmi','children','sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.svm import SVR

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'kernel': ['rbf', 'linear'],'C':[10,100]}
grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# C:\Users\deepa\ANACONDA3\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100], 'kernel': ['rbf', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'C': 100, 'kernel': 'linear'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.484520      0.018124         0.178065        0.009714       10
# 1       0.375951      0.075688         0.053468        0.009188       10
# 2       0.333209      0.005743         0.149967        0.023941      100
# 3       0.515454      0.047418         0.036922        0.008197      100
#
#   param_kernel                          params  split0_test_score  \
# 0          rbf      {'C': 10, 'kernel': 'rbf'}          -0.110409
# 1       linear   {'C': 10, 'kernel': 'linear'}          -0.018943
# 2          rbf     {'C': 100, 'kernel': 'rbf'}          -0.160182
# 3       linear  {'C': 100, 'kernel': 'linear'}           0.559313
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0          -0.097459          -0.074488          -0.099597          -0.124428
# 1           0.029886           0.022167           0.003112          -0.066653
# 2          -0.107253          -0.123430          -0.137753          -0.209551
# 3           0.521798           0.547691           0.538805           0.508518
#
#    mean_test_score  std_test_score  rank_test_score
# 0        -0.101276        0.016459                3
# 1        -0.006086        0.034672                2
# 2        -0.147634        0.035511                4
# 3         0.535225        0.018122                1

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 28
# BMI: 30
# Children: 3
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[19108.72771336]
# C:\Users\deepa\ANACONDA3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
